# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
array1=np.array([24,14,12,26,25])
array2=np.array([87,90,56,22,34])
# array3=np.array([67,90,86,22,34])
array4=np.array([97,90,6,22,34])
array5=np.array([97,90,56,20,34])

# %%
plt.scatter(array1,array2,array4,array5)
plt.show()
